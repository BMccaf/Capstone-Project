# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_excel('Final_Capstone_Spreadsheet.xlsx')

# %%
df.head()
# Out:
#    Rank      Company Name  Ticker Symbol Country of Origin  Company Age  \
# 0     1  Johnson & Johnson           JNJ               USA          136
# 1     2          Eli Lilly           LLY               USA          146
# 2     3             Pfizer           PFE               USA          173
# 3     4              Roche        ROG.SW        Switerland          126
# 4     5       Novo Nordisk           NVO           Denmark           98
#
#    Est. Market Capitalization  Total Liabilities  D/E Ratio  \
# 0                449870000000       101367000000   0.225325
# 1                292110000000        38404400000   0.131472
# 2                276440000000       101155000000   0.365920
# 3                247350000000        57790000000   0.233637
# 4                262070000000       144476000000   0.551288
#
#    R&D Expense 3rd Quarter 2021  R&D Expense 3rd Quarter 2020  \
# 0                        3422.0                       2840.00
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Company Name ', 'Ticker Symbol', 'Country of Origin',
#        'Company Age', 'Est. Market Capitalization', 'Total Liabilities',
#        'D/E Ratio', 'R&D Expense 3rd Quarter 2021',
#        'R&D Expense 3rd Quarter 2020', 'R&D Expense 3rd Quarter 2019',
#        'R&D Expense 3rd Quarter 2018',
#        'Number of Research Areas Covered by R&D Pipeline',
#        'No. of Ongoing Phase 1 Clinical Trials',
#        'No. of Ongoing Phase 2 Clinical Trials',
#        'No. of Ongoing Phase 3 Clinical Trials', 'Filed', 'Total in Pipeline',
#        'Total Approved Treatments on the Market in the U.S.A. ',
#        'No. of Employees'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Rank  Company Age  Est. Market Capitalization  Total Liabilities  \
# count  20.00000    20.000000                2.000000e+01       2.000000e+01
# mean   10.50000    75.500000                1.686825e+11       5.790276e+10
# std     5.91608    57.533057                1.053691e+11       4.053955e+10
# min     1.00000     9.000000                4.927000e+10       3.648700e+09
# 25%     5.75000    25.250000                7.638000e+10       3.081780e+10
# 50%    10.50000    45.500000                1.428100e+11       5.884700e+10
# 75%    15.25000   132.000000                2.447850e+11       7.167825e+10
# max    20.00000   173.000000                4.498700e+11       1.444760e+11
#
#        D/E Ratio  R&D Expense 3rd Quarter 2021  R&D Expense 3rd Quarter 2020  \
# count  20.000000                     20.000000                     20.000000
# mean    0.378619                   1974.507500                   1819.932500
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Company Name ', 'Ticker Symbol', 'Country of Origin',
#        'Company Age', 'Est. Market Capitalization', 'Total Liabilities',
#        'D/E Ratio', 'R&D Expense 3rd Quarter 2021',
#        'R&D Expense 3rd Quarter 2020', 'R&D Expense 3rd Quarter 2019',
#        'R&D Expense 3rd Quarter 2018',
#        'Number of Research Areas Covered by R&D Pipeline',
#        'No. of Ongoing Phase 1 Clinical Trials',
#        'No. of Ongoing Phase 2 Clinical Trials',
#        'No. of Ongoing Phase 3 Clinical Trials', 'Filed', 'Total in Pipeline',
#        'Total Approved Treatments on the Market in the U.S.A. ',
#        'No. of Employees'],
#       dtype='object')

# %%
plt.hist(df['D/E Ratio'])
# Out:
# (array([6., 5., 4., 3., 0., 1., 0., 0., 0., 1.]),
#  array([0.04953435, 0.19841645, 0.34729856, 0.49618067, 0.64506277,
#         0.79394488, 0.94282698, 1.09170909, 1.2405912 , 1.3894733 ,
#         1.53835541]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Total Approved Treatments on the Market in the U.S.A. '])
# Out:
# (array([9., 5., 3., 2., 0., 0., 0., 0., 0., 1.]),
#  array([  1. ,  32.3,  63.6,  94.9, 126.2, 157.5, 188.8, 220.1, 251.4,
#         282.7, 314. ]),
#  <BarContainer object of 10 artists>)

# %%
df[['Company Age', 'Est. Market Capitalization', 'Total Liabilities',
       'D/E Ratio', 'R&D Expense 3rd Quarter 2020', 'R&D Expense 3rd Quarter 2019',
       'R&D Expense 3rd Quarter 2018', 'Number of Research Areas Covered by R&D Pipeline',
       'No. of Ongoing Phase 1 Clinical Trials',
       'No. of Ongoing Phase 2 Clinical Trials',
       'No. of Ongoing Phase 3 Clinical Trials', 'Filed', 'Total in Pipeline',
       'Total Approved Treatments on the Market in the U.S.A. ',
       'No. of Employees']].corr()
# Out:
#                                                     Company Age  \
# Company Age                                            1.000000
# Est. Market Capitalization                             0.495697
# Total Liabilities                                      0.333965
# D/E Ratio                                              0.205140
# R&D Expense 3rd Quarter 2020                           0.489173
# R&D Expense 3rd Quarter 2019                           0.296671
# R&D Expense 3rd Quarter 2018                           0.274445
# Number of Research Areas Covered by R&D Pipeline       0.036090
# No. of Ongoing Phase 1 Clinical Trials                 0.021039
# No. of Ongoing Phase 2 Clinical Trials                 0.208459
# No. of Ongoing Phase 3 Clinical Trials                 0.148767
# Filed                                                  0.291961
# Total in Pipeline                                      0.190711
# Total Approved Treatments on the Market in the ...     0.441297
# ...

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['Company Age', 'Est. Market Capitalization', 'Total Liabilities',
       'D/E Ratio', 'R&D Expense 3rd Quarter 2020', 'R&D Expense 3rd Quarter 2019',
       'R&D Expense 3rd Quarter 2018', 'Number of Research Areas Covered by R&D Pipeline',
       'No. of Ongoing Phase 1 Clinical Trials',
       'No. of Ongoing Phase 2 Clinical Trials',
       'No. of Ongoing Phase 3 Clinical Trials', 'Filed', 'Total in Pipeline',
       'Total Approved Treatments on the Market in the U.S.A. ',
       'No. of Employees']].corr(), vmax=.3, center=0, cmap=cmap, square=True, linewidth=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Rank', 'Company Name ', 'Ticker Symbol', 'Country of Origin',
#        'Company Age', 'Est. Market Capitalization', 'Total Liabilities',
#        'D/E Ratio', 'R&D Expense 3rd Quarter 2021',
#        'R&D Expense 3rd Quarter 2020', 'R&D Expense 3rd Quarter 2019',
#        'R&D Expense 3rd Quarter 2018',
#        'Number of Research Areas Covered by R&D Pipeline',
#        'No. of Ongoing Phase 1 Clinical Trials',
#        'No. of Ongoing Phase 2 Clinical Trials',
#        'No. of Ongoing Phase 3 Clinical Trials', 'Filed', 'Total in Pipeline',
#        'Total Approved Treatments on the Market in the U.S.A. ',
#        'No. of Employees'],
#       dtype='object')

# %%
df_cat = df[['Company Name ', 'Ticker Symbol', 'Country of Origin', 'No. of Employees','Total Approved Treatments on the Market in the U.S.A. ']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Company Name : total = 20
# graph for Ticker Symbol: total = 20
# graph for Country of Origin: total = 8
# graph for No. of Employees: total = 20
# graph for Total Approved Treatments on the Market in the U.S.A. : total = 19

# %%
df.columns
# Out:
# Index(['Rank', 'Company Name ', 'Ticker Symbol', 'Country of Origin',
#        'Company Age', 'Est. Market Capitalization', 'Total Liabilities',
#        'D/E Ratio', 'R&D Expense 3rd Quarter 2021',
#        'R&D Expense 3rd Quarter 2020', 'R&D Expense 3rd Quarter 2019',
#        'R&D Expense 3rd Quarter 2018',
#        'Number of Research Areas Covered by R&D Pipeline',
#        'No. of Ongoing Phase 1 Clinical Trials',
#        'No. of Ongoing Phase 2 Clinical Trials',
#        'No. of Ongoing Phase 3 Clinical Trials', 'Filed', 'Total in Pipeline',
#        'Total Approved Treatments on the Market in the U.S.A. ',
#        'No. of Employees'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'Company Name ', values = 'D/E Ratio')
# Out:
#                            D/E Ratio
# Company Name
# AbbVie                      0.526782
# Amgen                       0.432082
# Astrazeneca                 0.312355
# Bayer                       1.538355
# Bristol-Myers Squibb        0.439613
# CSL                         0.058800
# Daiichi Sankyo              0.130853
# Eli Lilly                   0.131472
# Gilead Sciences             0.560075
# GlaxoSmithKline             0.797179
# Johnson & Johnson           0.225325
# Merck                       0.285906
# Moderna                     0.108438
# Novartis                    0.320000
# Novo Nordisk                0.551288
# Pfizer                      0.365920
# Regeneron Pharmaceuticals   0.098340
# Roche                       0.233637
# Sanofi                      0.406419
# Vertex Pharmaceuticals      0.049534

# %%
pd.pivot_table(df, index = ['Company Name ', 'Ticker Symbol'], values = ['D/E Ratio', 'Total Approved Treatments on the Market in the U.S.A. '])
# Out:
#                                          D/E Ratio  \
# Company Name              Ticker Symbol
# AbbVie                    ABBV            0.526782
# Amgen                     AMGN            0.432082
# Astrazeneca               AZN             0.312355
# Bayer                     BAYN.DE         1.538355
# Bristol-Myers Squibb      BMY             0.439613
# CSL                       CSL.AX          0.058800
# Daiichi Sankyo            4568.T          0.130853
# Eli Lilly                 LLY             0.131472
# Gilead Sciences           GILD            0.560075
# GlaxoSmithKline           GSK             0.797179
# Johnson & Johnson         JNJ             0.225325
# Merck                     MRK             0.285906
# Moderna                   MRNA            0.108438
# Novartis                  NVS             0.320000
# Novo Nordisk              NVO             0.551288
# Pfizer                    PFE             0.365920
# Regeneron Pharmaceuticals REGN            0.098340
# ...

# %%
pd.pivot_table(df, index = ['Company Name ', 'Est. Market Capitalization', 'No. of Employees'], values = ['Total in Pipeline']).sort_values('Total in Pipeline', ascending = False)
# Out:
#                                                                        Total in Pipeline
# Company Name              Est. Market Capitalization No. of Employees
# Roche                     247350000000               100920                          178
# Novartis                  187200000000               108000                          150
# GlaxoSmithKline           83300000000                90096                           150
# Bristol-Myers Squibb      153990000000               32200                           114
# Merck                     223070000000               67000                           109
# Astrazeneca               204620000000               83100                           108
# Pfizer                    276440000000               79000                           104
# Johnson & Johnson         449870000000               141700                           99
# Sanofi                    124310000000               95442                            87
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Company Name ', 'Ticker Symbol', 'Country of Origin',
#        'Company Age', 'Est. Market Capitalization', 'Total Liabilities',
#        'D/E Ratio', 'R&D Expense 3rd Quarter 2021',
#        'R&D Expense 3rd Quarter 2020', 'R&D Expense 3rd Quarter 2019',
#        'R&D Expense 3rd Quarter 2018',
#        'Number of Research Areas Covered by R&D Pipeline',
#        'No. of Ongoing Phase 1 Clinical Trials',
#        'No. of Ongoing Phase 2 Clinical Trials',
#        'No. of Ongoing Phase 3 Clinical Trials', 'Filed', 'Total in Pipeline',
#        'Total Approved Treatments on the Market in the U.S.A. ',
#        'No. of Employees'],
#       dtype='object')

# %%
#Rank, Company Age, R&D Expense 3rd Quarter 2021, Est. Market Capitalization, Total Approved Treatments on the Market in the U.S.A., Total Liabilities, Total in Pipeline

df_pivots = df[['Rank', 'Company Age', 'R&D Expense 3rd Quarter 2021', 'Est. Market Capitalization', 'Total Approved Treatments on the Market in the U.S.A. ', 'Total Liabilities', 'Total in Pipeline', 'Number of Research Areas Covered by R&D Pipeline']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots,index = i, values='Total in Pipeline').sort_values('Total in Pipeline', ascending = False))
# Out:
# Rank
#       Total in Pipeline
# Rank
# 4                   178
# 14                  150
# 9                   150
# 10                  114
# 7                   109
# 8                   108
# 3                   104
# 1                    99
# 12                   87
# 2                    84
# 6                    71
# 15                   60
# 20                   45
# 11                   44
# 18                   41
# 19                   39
# 13                   32
# 16                   31
# 5                    30
# 17                   13
# Company Age
#              Total in Pipeline
# Company Age
# 126                        178
# 21                         150
# 26                         150
# 135                        114
# 131                        109
# 23                         108
# 173                        104
# 136                         99
# 49                          87
# 146                         84
# 9                           71
# ...

# %%
pd.pivot_table(df_pivots, index = 'R&D Expense 3rd Quarter 2021', columns = 'Number of Research Areas Covered by R&D Pipeline', values = 'Total Approved Treatments on the Market in the U.S.A. ', aggfunc = 'count')
# Out:
# Number of Research Areas Covered by R&D Pipeline   3    4    5    6    7   \
# R&D Expense 3rd Quarter 2021
# 250.25                                            NaN  NaN  NaN  1.0  NaN
# 493.00                                            1.0  NaN  NaN  NaN  NaN
# 499.00                                            1.0  NaN  NaN  NaN  NaN
# 521.00                                            NaN  NaN  NaN  NaN  NaN
# 665.00                                            NaN  NaN  NaN  NaN  NaN
# 1147.00                                           1.0  NaN  NaN  NaN  NaN
# 1422.00                                           NaN  NaN  NaN  NaN  1.0
# 1701.00                                           NaN  NaN  NaN  1.0  NaN
# 1708.90                                           NaN  NaN  1.0  NaN  NaN
# 1771.00                                           NaN  NaN  NaN  NaN  NaN
# 1844.00                                           NaN  1.0  NaN  NaN  NaN
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Company Name ', 'Ticker Symbol', 'Country of Origin',
#        'Company Age', 'Est. Market Capitalization', 'Total Liabilities',
#        'D/E Ratio', 'R&D Expense 3rd Quarter 2021',
#        'R&D Expense 3rd Quarter 2020', 'R&D Expense 3rd Quarter 2019',
#        'R&D Expense 3rd Quarter 2018',
#        'Number of Research Areas Covered by R&D Pipeline',
#        'No. of Ongoing Phase 1 Clinical Trials',
#        'No. of Ongoing Phase 2 Clinical Trials',
#        'No. of Ongoing Phase 3 Clinical Trials', 'Filed', 'Total in Pipeline',
#        'Total Approved Treatments on the Market in the U.S.A. ',
#        'No. of Employees'],
#       dtype='object')

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['Company Age', 'Est. Market Capitalization',
       'D/E Ratio', 'R&D Expense 3rd Quarter 2020', 'R&D Expense 3rd Quarter 2019',
       'R&D Expense 3rd Quarter 2018',
       'Total Approved Treatments on the Market in the U.S.A. ',
       'No. of Employees']].corr(), vmax=.3, center=0, cmap=cmap, square=True, linewidth=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>
